# %%
# 1. 고객의 정보는 이름, 계좌번호, 예금금액만 관리할 것(0)
# 2. 계좌번호는 정수값을 가지되, 중복값을 허용하지 않는다.(0)
# 3. 둘 이상의 고객에 대한 정보를 저장할 수 있도록 구현할 것.(0)
# 4. 계좌개설, 입금처리, 출금처리, 전체고객에 대한 계좌잔액 출력에 관한 로직을 구현할 것.(세모)
# 5. 입금처리는 계좌번호를 입력받아 해당계좌의 존재유무에 따라 처리가 되도록 구현하되,
#    입력한 계좌번호가 존재하지 않을 경우 "계좌번호가 존재하지 않습니다." 라는 메시지가 출력되도록
#    구현할 것.(0)
# 6. 출금처리는 계좌번호를 입력받아 해당계좌의 존재유무에 따라 처리하는 로직은 입금처리와 동일하며,
#    출금처리시 계좌의 잔액 유무에 따른 메시지가 출력되도록 구현할 것.
#    즉, 출금금액보다 예금잔액이 부족할 경우 "잔액이 부족합니다."라는 메시지 출력할 것.
# 7. 기타 처리 기능은 일반적으로 통용되는 기능을 이용할 것.
# 8. 아래 출력형식에 맞게 프로그램을 구현할 것.

# %%
#리스트 선언
_number = []

# %%
#계좌개설

class Account:  # 이름, 계좌번호, 예금금액
    # 멤버 필드
    name = ''
    number = set()
    coin = int()
    
    # 생성자 메서드
    
    def __init__(self, name, number, coin):
        self.name = name
        self.number = number
        self.coin = coin

    # 멤버 메서드
    def disp(self):
        print('== 계좌개설 ==')
        print('계좌번호 = ', self.number)
        print('고객이름 = ', self.name)
        print('예금금액 = ', self.coin)
        print('------------------')
        print('계좌개설이 완료되었습니다.')

# %%
#입금처리            
class Input:
     # 멤버 필드
    number = int()
    
     # 생성자 메서드
    
    def __init__(self,number):
    self.number = number

    def play(self): 
        num = int(input('계좌번호를 입력하세요: ')
        if num == number:
            money = int(input('입금하실 돈을 입력하세요: ')) 
                print(' == 입금처리 == ')
                print(' 계좌번호 = ', self.number)
                print(' 입금금액 = ' + str(coin += money) )
                print('----------------')
                print('입금이 완료되었습니다.')
        else:
            print(' == 입금처리 ==')
            print(' 계좌번호 = ', self.number)
            print('--------------')
            print('계좌번호가 존재하지 않습니다.')

# %%
#출금처리            
class Out_money:
     # 멤버 필드
    number = set(int())
    
     # 생성자 메서드
    
    def __init__(self,number):
        self.number = number
            
                    
    def spell(self):
                
        num = int(input('계좌번호를 입력하세요: ')            
        if num == number:
            money = int(input('출금하실 돈을 입력하세요: '))
            if coin > money: 
                print(' == 출금처리 == ')
                print(' 계좌번호 = ', self.number)
                print(' 입금금액 = ' + str(coin -= money))
                print('----------------')
                print('입금이 완료되었습니다.')
            else:
                print(' == 출금처리 ==')
                print(' 계좌번호 = ',self.number )
                print('--------------')
                print('잔액이 부족합니다.')

# %%
#전체고객 잔액조회

class Customer:  # 이름, 계좌번호, 예금금액
    # 멤버 필드
    name = ''
    number = set()
    coin = int()
    
    # 생성자 메서드
    
    def __init__(self, name, number, coin):
        self.name = name
        self.number = number
        self.coin = coin
    
    # 멤버 메서드
    def ell(self):
        print('== 전체고객 잔액조회 ==')
        print('계좌번호   고객이름   예금잔액')
        print('----------------------------------')
        for number in  :
            pass
            print(self.number, self.name, self.coin, sep = '\t')
        print('----------------------------------')
            print('       총 보유예금액 :',coin)
# Out:
#   Input In [28]
#     def disp(self):
#     ^
# IndentationError: unexpected indent

# %%
#메뉴 프로그램
              
                
while True:
    print(    '<출력형식>')
    print('== 계좌관리 프로그램 ==')
    print('1. 계좌개설')
    print('2. 입금처리')
    print('3. 출금처리')
    print('4. 전체고객 잔액조회')
    print('5. 프로그램 종료')
    print('=====================')
    
    a = int(input('메뉴 = ' ))
    
    if a == 1:
        Account.disp()
    elif a == 2:
        Input.play()
    elif a == 3: 
        Out_money.spell()
    elif a == 4:
        Customer.ell()
    elif a == 5:
        print('프로그램을 종료합니다.')
        break
    else:
        print('잘못된 선택입니다.')
        
        ## 반복문을 어떻게 만드는 것이 좋을까요?? 리스트 형태를 만들었는데 어떻게 반복문을 만들어야 할지 모르겠습니다.....
# Out:
#   Input In [31]
#     self.number = number
#     ^
# IndentationError: expected an indented block

# %%
#계좌개설

class Account:  # 이름, 계좌번호, 예금금액
    # 멤버 필드
    name = ''
    number = set(int())
    coin = int()
    
    # 생성자 메서드
    
    def __init__(self, name, number, coin):
        self.name = name
        self.number = number
        self.coin = coin
    
    # 멤버 메서드
    def disp(self):
        print('== 계좌개설 ==')
        print('계좌번호 = ', self.number)
        print('고객이름 = ', self.name)
        print('예금금액 = ', self.coin)
        print('------------------')
        print('계좌개설이 완료되었습니다.')
              

#입금처리            
class Input:
     # 멤버 필드
    number = set(int())
    
     # 생성자 메서드
    
    def __init__(self,number):
    self.number = number

    def play(self):
        money = 0   
        b = int(input('계좌번호를 입력하세요: ')
        if b True:
            c = int(input('입금하실 돈을 입력하세요: '))
                if c > 0: 
                print(' == 입금처리 == ')
                print(' 계좌번호 = ', self.number)
                print(' 입금금액 = ' + str(money += c) )
                print('----------------')
                print('입금이 완료되었습니다.')
        else:
            print(' == 입금처리 ==')
            print(' 계좌번호 = ', self.number)
            print('--------------')
            print('계좌번호가 존재하지 않습니다.')
        
#출금처리            
class Out_money:
     # 멤버 필드
    number = set(int())
    
     # 생성자 메서드
    
    def __init__(self,number):
        self.number = number
            
                    
    def spell(self):
                
        d = int(input('계좌번호를 입력하세요: ')            
        if d True:
            e = int(input('출금하실 돈을 입력하세요: '))
            if e > 0: 
                print(' == 출금처리 == ')
                print(' 계좌번호 = ', self.number)
                print(' 입금금액 = ' + str(money -= e) )
                print('----------------')
                print('입금이 완료되었습니다.')
            else:
                print(' == 출금처리 ==')
                print(' 계좌번호 = ',self.number )
                print('--------------')
                print('잔액이 부족합니다.')
                
#전체고객 잔액조회

class Customer:  # 이름, 계좌번호, 예금금액
    # 멤버 필드
    name = ''
    number = set(int())
    coin = int()
    
    # 생성자 메서드
    
    def __init__(self, name, number, coin):
        self.name = name
        self.number = number
        self.coin = coin
    
    # 멤버 메서드
    def ell(self):
        print('== 전체고객 잔액조회 ==')
        print('계좌번호   고객이름   예금잔액')
        print('----------------------------------')
        print(self.number, self.name, self.coin, sep = '\t')
        print('----------------------------------')
        print('       총 보유예금액 :',money)
              
                
while True:
    print(    '<출력형식>')
    print('== 계좌관리 프로그램 ==')
    print('1. 계좌개설')
    print('2. 입금처리')
    print('3. 출금처리')
    print('4. 전체고객 잔액조회')
    print('5. 프로그램 종료')
    print('=====================')
    
    a = int(input('메뉴 = ' ))
    
    if a == 1:
        Account.disp()
    elif a == 2:
        Input.play()
    elif a == 3: 
        Out_money.spell()
    elif a == 4:
        Customer.ell()
    elif a == 5:
        print('프로그램을 종료합니다.')
        break
    else:
        print('잘못된 선택입니다.')
# Out:
#   Input In [12]
#     self.number = number
#     ^
# IndentationError: expected an indented block
